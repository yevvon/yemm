# %% [markdown]
# <a href="https://colab.research.google.com/github/yevvon/yemm/blob/main/Metal_Measuring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'http://apis.data.go.kr/B552584/OzYlwsndOccrrncInforInqireSvc/getOzAdvsryOccrrncInfo'
params ={'serviceKey' : 'CyfiNQ9+n+ByaG2g0r2XpUbjNkzErg3A8KNIVrOXPKz4VTkfRpR2uNw7Pm1zArKvOSDSHp9/0N3hDg8isI4fEg==', 'returnType' : 'xml', 'numOfRows' : '100', 'pageNo' : '1', 'year' : '2023' }

response = requests.get(url, params=params)
print(response.content.decode('utf'))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <clearVal>.113</clearVal>
#         <sn>348</sn>
#         <maxVal>.126</maxVal>
#         <districtName>경남</districtName>
#         <dataDate>2023-10-18</dataDate>
#         <issueVal>.126</issueVal>
#         <issueLvl>1</issueLvl>
#         <issueTime>16</issueTime>
#         <moveName>진주시</moveName>
#         <clearTime>17</clearTime>
#       </item>
#       <item>
#         <clearVal>.1044</clearVal>
#         <sn>347</sn>
#         <maxVal>.1286</maxVal>
#         <districtName>전남</districtName>
#         <dataDate>2023-10-04</dataDate>
#         <issueVal>.1286</issueVal>
#         <issueLvl>1</issueLvl>
#         <issueTime>13</issueTime>
#         <moveName>여수시</moveName>
#         <clearTime>14</clearTime>
#       </item>
#       <item>
#         <clearVal>.1101</clearVal>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content.decode('utf'), features="xml")

# %%
soup.find_all('issueVal')
# Out:
# [<issueVal>.126</issueVal>,
#  <issueVal>.1286</issueVal>,
#  <issueVal>.1221</issueVal>,
#  <issueVal>.126</issueVal>,
#  <issueVal>.1353</issueVal>,
#  <issueVal>.122</issueVal>,
#  <issueVal>.1253</issueVal>,
#  <issueVal>.1245</issueVal>,
#  <issueVal>.1248</issueVal>,
#  <issueVal>.1216</issueVal>,
#  <issueVal>.1205</issueVal>,
#  <issueVal>.1307</issueVal>,
#  <issueVal>.1403</issueVal>,
#  <issueVal>.122</issueVal>,
#  <issueVal>.1215</issueVal>,
#  <issueVal>.1212</issueVal>,
#  <issueVal>.1221</issueVal>,
#  <issueVal>.1403</issueVal>,
#  <issueVal>.1323</issueVal>,
#  <issueVal>.1338</issueVal>,
#  <issueVal>.121</issueVal>,
#  <issueVal>.1285</issueVal>,
#  <issueVal>.1223</issueVal>,
#  <issueVal>.1348</issueVal>,
#  <issueVal>.1344</issueVal>,
#  <issueVal>.12</issueVal>,
#  <issueVal>.1239</issueVal>,
#  <issueVal>.1496</issueVal>,
#  <issueVal>.138</issueVal>,
#  <issueVal>.1304</issueVal>,
#  <issueVal>.1242</issueVal>,
#  <issueVal>.1205</issueVal>,
# ...

# %%
print('학번=', 2370083, '이름=', '최예원')
# Out:
# 학번= 2370083 이름= 최예원
